# %% [markdown]
# ## import 모음

# %%
import pandas as pd
import numpy as np
import folium as g
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/서울시자치구별등록동물수.csv', encoding='cp949')

# %%
df_sorted = df.sort_values("등록동물수", ascending=False)
df_sorted
# Out:
#     Unnamed: 0   자치구  등록동물수     소유자수  소유자당반려동물수  반려동물출입가능식당개수  동물병원개수  동물약국개수
# 13          13  서대문구  46266      0.0        inf             8      24      55
# 12          12   마포구  38948      0.0        inf            48      46      86
# 0            0   강남구  31371  24141.0   1.299490            20      83     219
# 2            2   강북구  31286  24304.0   1.287278             3      26      74
# 17          17   송파구  30488  24411.0   1.248945             8      68     172
# 21          21   은평구  28578  21868.0   1.306841            10      43     101
# 8            8   노원구  28129  24591.0   1.143874             3      43      81
# 3            3   강서구  28055  21841.0   1.284511             3      47     117
# 4            4   관악구  25027  18669.0   1.340565             2      29      85
# 18          18   양천구  24563      0.0        inf             2      49      76
# 14          14   서초구  23953  18748.0   1.277630            15      53     122
# ...

# %%
register_sorted = df.drop([9,12,13,15,18], axis=0, inplace=False)

register_sorted = register_sorted.sort_values("등록동물수", ascending=False)
register_sorted
# Out:
#     Unnamed: 0   자치구  등록동물수     소유자수  소유자당반려동물수  반려동물출입가능식당개수  동물병원개수  동물약국개수
# 0            0   강남구  31371  24141.0   1.299490            20      83     219
# 2            2   강북구  31286  24304.0   1.287278             3      26      74
# 17          17   송파구  30488  24411.0   1.248945             8      68     172
# 21          21   은평구  28578  21868.0   1.306841            10      43     101
# 8            8   노원구  28129  24591.0   1.143874             3      43      81
# 3            3   강서구  28055  21841.0   1.284511             3      47     117
# 4            4   관악구  25027  18669.0   1.340565             2      29      85
# 14          14   서초구  23953  18748.0   1.277630            15      53     122
# 16          16   성북구  21877  16965.0   1.289537             5      33      64
# 24          24   중랑구  19622  15454.0   1.269704             3      30      62
# 10          10  동대문구  19565  14461.0   1.352949             3      28      69
# ...

# %%
plt.rcParams['font.family'] = 'NanumGothic'

f, ax = plt.subplots(figsize=(6, 15))

sns.set_color_codes("pastel")
sns.barplot(x="등록동물수", y="자치구", data=df_sorted,
            label="등록동물수", color="b")

sns.set_color_codes("muted")
sns.barplot(x="소유자수", y="자치구", data=df_sorted,
            label="소유자수", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 45000), ylabel="",
       xlabel="자치구별 등록동물수와 소유자수")

sns.despine(left=True, bottom=True)

# %%
plt.rcParams['font.family'] = 'NanumGothic'

f, ax = plt.subplots(figsize=(15, 6))
ax.xaxis.label.set_size(16)
f.suptitle('자치구별 등록동물수와 소유자수', fontsize=26, fontweight='medium')
sns.set_color_codes("pastel")
sns.barplot(x="자치구", y="등록동물수", data=df_sorted,
            label="등록동물수", color="b")

sns.set_color_codes("muted")
sns.barplot(x="자치구", y="소유자수", data=df_sorted,
            label="소유자수", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="upper right", frameon=True, fontsize=13)
ax.set(ylim=(0, 50000), ylabel="등록동물수 및 소유자수",
       xlabel="서울특별시 자치구")

sns.despine(left=True, bottom=True)
plt.savefig('./data/서울시_자치구별_등록동물수와 소유자수.png',
            facecolor='#eeeeee',
            edgecolor='black',
            format='png', dpi=200)

# %%
plt.rcParams['font.family'] = 'NanumGothic'

f, ax = plt.subplots(figsize=(6, 15))

sns.set_color_codes("pastel")
sns.barplot(x="등록동물수", y="자치구", data=register_sorted,
            label="등록동물수", color="b")

sns.set_color_codes("muted")
sns.barplot(x="소유자수", y="자치구", data=register_sorted,
            label="소유자수", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 45000), ylabel="",
       xlabel="자치구별 등록동물수와 소유자수")

sns.despine(left=True, bottom=True)

# %%
plt.rcParams['font.family'] = 'NanumGothic'

f, ax = plt.subplots(figsize=(15, 6))

sns.set_color_codes("pastel")
sns.barplot(x="자치구", y="등록동물수", data=register_sorted,
            label="등록동물수", color="b")

sns.set_color_codes("muted")
sns.barplot(x="자치구", y="소유자수", data=register_sorted,
            label="소유자수", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="upper right", frameon=True, fontsize=16)
ax.set(ylim=(0, 45000), ylabel="",
       xlabel="자치구별 등록동물수와 소유자수", )

sns.despine(left=True, bottom=True)
plt.savefig('./data/서울시_자치구별_등록동물수와 소유자수.png',
           facecolor='#eeeeee',
            edgecolor='black',
            format='png', dpi=200)

# %% [markdown]
# # 자치구별 동물등록수

# %%
register = pd.read_csv('./data/(최종)서울시동물등록현황.csv', encoding='cp949')

# %%
register[:3]
# Out:
#    자치구  법정동  등록동물수    소유자수  소유자당반려동물수
# 0  강남구  개포동   3189  2459.0       1.30
# 1  강남구  논현동   3890  2792.0       1.39
# 2  강남구  대치동   4209  3446.0       1.22

# %%
register_grouped = register.groupby('자치구', as_index=False)['등록동물수', '소유자수', '소유자당반려동물수'].agg({'등록동물수':sum, '소유자수':sum,
                                                             '소유자당반려동물수':np.mean})
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_15740\3704881640.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   register_grouped = register.groupby('자치구', as_index=False)['등록동물수', '소유자수', '소유자당반려동물수'].agg({'등록동물수':sum, '소유자수':sum,

# %%
register_grouped.index
# Out:
# RangeIndex(start=0, stop=24, step=1)

# %%
register_grouped = register_grouped.sort_values(by='자치구', ignore_index=True)

# %%
register_grouped = register_grouped.iloc[:, :3]

# %%
register_grouped
# Out:
#      자치구  등록동물수     소유자수
# 0    강남구  30314  23324.0
# 1    강동구  18281  14522.0
# 2    강북구  15643  12152.0
# 3    강서구  26442  20522.0
# 4    관악구  25027  18669.0
# 5    광진구   2672   2328.0
# 6    구로구   8419   7034.0
# 7    금천구  12650   9783.0
# 8    노원구  28129  24591.0
# 9    도봉구  14676      0.0
# 10  동대문구  19311  14278.0
# 11   동작구  18145  14136.0
# 12   마포구  18646      0.0
# 13   서초구  23953  18748.0
# 14   성동구  16943      0.0
# 15   성북구  21877  16965.0
# 16   송파구  30488  24411.0
# 17   양천구  24563      0.0
# 18  영등포구  18825  14757.0
# 19   용산구  17717  12718.0
# 20   은평구  28578  21868.0
# 21   종로구   9753   7288.0
# 22    중구   7922   5951.0
# 23   중랑구  19622  15454.0

# %% [markdown]
# # 자치구별 동물병원 개수

# %% [markdown]
# ## 필요한 데이터 추출하여 객체 저장

# %%
hospital = pd.read_csv('./data/서울시/상권분석/서울시 동물병원 인허가 정보.csv', encoding='cp949')
hospital.columns
# Out:
# Index(['개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자', '영업상태코드', '영업상태명', '상세영업상태코드',
#        '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '전화번호', '소재지면적',
#        '소재지우편번호', '지번주소', '도로명주소', '도로명우편번호', '사업장명', '최종수정일자', '데이터갱신구분',
#        '데이터갱신일자', '업태구분명', '좌표정보(X)', '좌표정보(Y)', '축산업무구분명', '축산물가공업구분명',
#        '축산일련번호', '권리주체일련번호', '총인원'],
#       dtype='object')

# %%
hospital_y = hospital[hospital['상세영업상태코드'] == 0]

# 불필요한 데이터 제거
df = hospital_y.drop(['관리번호', '인허가취소일자', '영업상태코드', '영업상태명', '상세영업상태코드',
       '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '전화번호', '소재지면적', '소재지우편번호',
                 '지번주소', '도로명우편번호', '최종수정일자', '데이터갱신구분', '업태구분명', '축산업무구분명',
                 '축산물가공업구분명', '축산일련번호', '권리주체일련번호', '총인원', '좌표정보(X)', '좌표정보(Y)'], axis=1)

# 결측치 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 912 entries, 2 to 2051
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   개방자치단체코드  912 non-null    int64
#  1   인허가일자     912 non-null    int64
#  2   도로명주소     911 non-null    object
#  3   사업장명      912 non-null    object
#  4   데이터갱신일자   912 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 42.8+ KB

# %% [markdown]
# ## 좌표 구하기 (Geocode)

# %%
df.to_excel('./data/서울시/상권분석/서울시_동물병원_좌표구할자료.xlsx', encoding='utf-8-sig')

# %%
df = pd.read_excel('./data/서울시/상권분석/서울시_동물병원_좌표변환완료.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 903 entries, 0 to 902
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  903 non-null    int64
#  1   개방자치단체코드    903 non-null    int64
#  2   인허가일자       903 non-null    int64
#  3   도로명주소       903 non-null    object
#  4   Latitude    902 non-null    float64
#  5   Longitude   902 non-null    float64
#  6   사업장명        903 non-null    object
#  7   데이터갱신일자     903 non-null    object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 56.6+ KB

# %% [markdown]
# ## 결측치 처리

# %%
# 결측치가 있는 행만 모아 객체 저장
df_na = df[df['도로명주소'].isna() == True]

# 결측치 제거, 인덱스 정리
df = df.dropna(axis=0, inplace=False)
df.drop('Unnamed: 0', axis=1, inplace=True)
df = df.reset_index(drop=True)

# %% [markdown]
# ## 자치단체코드로 자치구 열 만들기

# %%
## 자치단체코드 파일 호출 후 정제하여 저장
code = pd.read_excel('./data/서울시/상권분석/[붙임1] 지방행정인허가데이터개방_자치단체코드목록.xlsx')

code = code[code['시군구(자치단체)코드'].apply(lambda x: (x >= 3000000) and (x <= 3240000))][['시군구명',
                                                                                     '시군구(자치단체)코드']]
code['시군구(자치단체)코드'] = code['시군구(자치단체)코드'].astype('int32')


# 자치구와 자치단체코드 정보를 저장하는 딕셔너리 생성. key : 자치구 , value : 자치단체코드
dic = {}
for i, j in zip(code['시군구명'], code['시군구(자치단체)코드']):
    dic[i] = j

# df 에 바로 열 추가할 수 없으므로 리스트에 저장함으로 우회
li = []
a = df['개방자치단체코드'].values

for i in range(np.shape(df)[0]):
    for j, code in enumerate(list(dic.values())):
        if a[i] == code :
            li.append(list(dic.keys())[j])

df['자치구'] = li
df.drop('개방자치단체코드', axis=1, inplace=True)

df
# Out:
#         인허가일자                                             도로명주소   Latitude  \
# 0    20220406  서울특별시 영등포구 신길로 29 105동 116호 (대림동 e편한세상 영등포 아델포레)  37.495231
# 1    20201109                         서울특별시 중랑구 동일로 925 3층 (묵동)  37.612946
# 2    20041206                          서울특별시 서대문구 통일로 375 (홍제동)  37.583551
# 3    20140314                           서울특별시 마포구 동교로 193 (동교동)  37.558078
# 4    20220530                    서울특별시 강남구 논현로 18 지수빌딩 2층 (개포동)  37.472968
# ..        ...                                               ...        ...
# 897  20160621                      서울특별시 송파구 새말로 125 어은회관 (문정동)  37.483075
# 898  20140521                     서울특별시 송파구 삼학사로 88 금보 1층 (석촌동)  37.504926
# 899  20100716        서울특별시 송파구 위례성대로 102 2층 202호 (방이동 태평양파크빌라트)  37.513292
# 900  19910430                      서울특별시 관악구 남부순환로 1747-1 (봉천동)  37.482348
# 901  19930702                      서울특별시 송파구 오금로 203 남양빌딩 (방이동)  37.508120
#
#       Longitude          사업장명                데이터갱신일자   자치구
# ...

# %% [markdown]
# ## value_counts() 데이터프레임

# %%
df['자치구'].value_counts().index
# Out:
# Index(['강남구', '송파구', '강동구', '서초구', '양천구', '강서구', '마포구', '은평구', '노원구', '성북구',
#        '영등포구', '광진구', '중랑구', '구로구', '성동구', '용산구', '관악구', '동대문구', '강북구', '도봉구',
#        '서대문구', '동작구', '중구', '금천구', '종로구'],
#       dtype='object')

# %%
hospital_count = pd.DataFrame(columns=['자치구', '동물병원개수'],
                             data= {'자치구':df['자치구'].value_counts().index,
                                   '동물병원개수':df['자치구'].value_counts().values})

# %%
hospital_count = hospital_count.sort_values(by='자치구', ignore_index=True)

# %%
hospital_count
# Out:
#      자치구  동물병원개수
# 0    강남구      83
# 1    강동구      54
# 2    강북구      26
# 3    강서구      47
# 4    관악구      29
# 5    광진구      32
# 6    구로구      30
# 7    금천구      17
# 8    노원구      43
# 9    도봉구      25
# 10  동대문구      28
# 11   동작구      20
# 12   마포구      46
# 13  서대문구      24
# 14   서초구      53
# 15   성동구      30
# 16   성북구      33
# 17   송파구      68
# 18   양천구      49
# 19  영등포구      33
# 20   용산구      29
# 21   은평구      43
# 22   종로구      11
# 23    중구      19
# 24   중랑구      30

# %% [markdown]
# # 자치구별 동물약국 개수

# %%
medicine = pd.read_csv('./data/서울시/상권분석/서울시 동물약국 인허가 정보.csv', encoding='cp949')
medicine.columns
# Out:
# Index(['개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자', '영업상태코드', '영업상태명', '상세영업상태코드',
#        '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '전화번호', '소재지면적',
#        '소재지우편번호', '지번주소', '도로명주소', '도로명우편번호', '사업장명', '최종수정일자', '데이터갱신구분',
#        '데이터갱신일자', '업태구분명', '좌표정보(X)', '좌표정보(Y)', '축산업무구분명', '축산물가공업구분명',
#        '축산일련번호', '권리주체일련번호', '총인원'],
#       dtype='object')

# %%
medicine_y = medicine[medicine['상세영업상태코드'] == 0]

# 불필요한 데이터 제거
df = medicine_y.drop(['관리번호', '인허가취소일자', '영업상태코드', '영업상태명', '상세영업상태코드',
       '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '전화번호', '소재지면적', '소재지우편번호',
                 '지번주소', '도로명우편번호', '최종수정일자', '데이터갱신구분', '업태구분명', '축산업무구분명',
                 '축산물가공업구분명', '축산일련번호', '권리주체일련번호', '총인원', '좌표정보(X)', '좌표정보(Y)'], axis=1)

# 결측치 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2091 entries, 1 to 3127
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   개방자치단체코드  2091 non-null   int64
#  1   인허가일자     2091 non-null   int64
#  2   도로명주소     2053 non-null   object
#  3   사업장명      2091 non-null   object
#  4   데이터갱신일자   2091 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 98.0+ KB

# %% [markdown]
# ## 결측치 처리

# %%
# 결측치가 있는 행만 모아 객체 저장
df_na = df[df['도로명주소'].isna() == True]

# 결측치 제거, 인덱스 정리
df = df.dropna(axis=0, inplace=False)
df = df.reset_index(drop=True)
df
# Out:
#       개방자치단체코드     인허가일자                                       도로명주소     사업장명  \
# 0      3190000  20220422  서울특별시 동작구 흑석한강로 27 A동 B106호 (흑석동 흑석한강푸르지오)  우리온누리약국
# 1      3110000  20220422    서울특별시 은평구 가좌로 330 명남더블레스 지하3층 303호 (신사동)   웃음짓는약국
# 2      3240000  20220421        서울특별시 강동구 천호대로 1037 세우빌딩 1층 2호 (천호동)     이화약국
# 3      3140000  20220516                   서울특별시 양천구 월정로 57 1층 (신월동)      한약국
# 4      3080000  20220516              서울특별시 강북구 노해로 87 광산빌딩 1층 (수유동)     새봄약국
# ...        ...       ...                                         ...      ...
# 2048   3160000  20221013     서울특별시 구로구 디지털로26길 123 지플러스타워 105호 (구로동)     고래약국
# 2049   3160000  20221013                  서울특별시 구로구 경인로 201 1층 (오류동)  오류온누리약국
# 2050   3230000  20221013                 서울특별시 송파구 성내천로34길 24-1(마천동)     보영약국
# 2051   3220000  20130605                   서울특별시 강남구 압구정로20길 15(신사동)  압구정스타약국
# 2052   3160000  20221014                   서울특별시 구로구 개봉로 68 1층 (개봉동)     은하약국
#
#                     데이터갱신일자
# ...

# %% [markdown]
# ## 자치단체코드로 자치구 열 만들기

# %%
## 자치단체코드 파일 호출 후 정제하여 저장
code = pd.read_excel('./data/서울시/상권분석/[붙임1] 지방행정인허가데이터개방_자치단체코드목록.xlsx')

code = code[code['시군구(자치단체)코드'].apply(lambda x: (x >= 3000000) and (x <= 3240000))][['시군구명',
                                                                                     '시군구(자치단체)코드']]
code['시군구(자치단체)코드'] = code['시군구(자치단체)코드'].astype('int32')


# 자치구와 자치단체코드 정보를 저장하는 딕셔너리 생성. key : 자치구 , value : 자치단체코드
dic = {}
for i, j in zip(code['시군구명'], code['시군구(자치단체)코드']):
    dic[i] = j

# df 에 바로 열 추가할 수 없으므로 리스트에 저장함으로 우회
li = []
a = df['개방자치단체코드'].values

for i in range(np.shape(df)[0]):
    for j, code in enumerate(list(dic.values())):
        if a[i] == code :
            li.append(list(dic.keys())[j])

df['자치구'] = li
df.drop('개방자치단체코드', axis=1, inplace=True)

df
# Out:
#          인허가일자                                       도로명주소     사업장명  \
# 0     20220422  서울특별시 동작구 흑석한강로 27 A동 B106호 (흑석동 흑석한강푸르지오)  우리온누리약국
# 1     20220422    서울특별시 은평구 가좌로 330 명남더블레스 지하3층 303호 (신사동)   웃음짓는약국
# 2     20220421        서울특별시 강동구 천호대로 1037 세우빌딩 1층 2호 (천호동)     이화약국
# 3     20220516                   서울특별시 양천구 월정로 57 1층 (신월동)      한약국
# 4     20220516              서울특별시 강북구 노해로 87 광산빌딩 1층 (수유동)     새봄약국
# ...        ...                                         ...      ...
# 2048  20221013     서울특별시 구로구 디지털로26길 123 지플러스타워 105호 (구로동)     고래약국
# 2049  20221013                  서울특별시 구로구 경인로 201 1층 (오류동)  오류온누리약국
# 2050  20221013                 서울특별시 송파구 성내천로34길 24-1(마천동)     보영약국
# 2051  20130605                   서울특별시 강남구 압구정로20길 15(신사동)  압구정스타약국
# 2052  20221014                   서울특별시 구로구 개봉로 68 1층 (개봉동)     은하약국
#
#                     데이터갱신일자  자치구
# 0     2021-12-03 22:04:00.0  동작구
# 1     2021-12-03 22:04:00.0  은평구
# 2     2021-12-03 22:03:00.0  강동구
# ...

# %%
'''
# 도로명주소에서 법정동명 추출하려 하였으나 실패
df['법정동'] = df['도로명주소'].str.extract(r'([(].+동[)])')
df['법정동'] = [df['법정동'][i][1:-1] for i in range(np.shape(df)[0])]

df['법정동'].value_counts()

df['도로명주소'].str.extract(r'([(][가-힣]+동[)])')

df[df['법정동'].apply(len) > 4]
'''
# Out:
# "\n# 도로명주소에서 법정동명 추출하려 하였으나 실패\ndf['법정동'] = df['도로명주소'].str.extract(r'([(].+동[)])')\ndf['법정동'] = [df['법정동'][i][1:-1] for i in range(np.shape(df)[0])]\n\ndf['법정동'].value_counts()\n\ndf['도로명주소'].str.extract(r'([(][가-힣]+동[)])')\n\ndf[df['법정동'].apply(len) > 4]\n"

# %% [markdown]
# ## value_counts() 데이터프레임

# %%
df['자치구'].value_counts().index
# Out:
# Index(['강남구', '송파구', '서초구', '강서구', '은평구', '강동구', '영등포구', '마포구', '관악구', '노원구',
#        '양천구', '강북구', '구로구', '동대문구', '성북구', '종로구', '중랑구', '광진구', '도봉구', '동작구',
#        '서대문구', '성동구', '금천구', '중구', '용산구'],
#       dtype='object')

# %%
medicine_count = pd.DataFrame(columns=['자치구', '동물약국개수'],
                             data= {'자치구':df['자치구'].value_counts().index,
                                   '동물약국개수':df['자치구'].value_counts().values})

# %%
medicine_count = medicine_count.sort_values(by='자치구', ignore_index=True)

# %%
medicine_count
# Out:
#      자치구  동물약국개수
# 0    강남구     219
# 1    강동구     100
# 2    강북구      74
# 3    강서구     117
# 4    관악구      85
# 5    광진구      61
# 6    구로구      74
# 7    금천구      47
# 8    노원구      81
# 9    도봉구      59
# 10  동대문구      69
# 11   동작구      55
# 12   마포구      86
# 13  서대문구      55
# 14   서초구     122
# 15   성동구      49
# 16   성북구      64
# 17   송파구     172
# 18   양천구      76
# 19  영등포구      89
# 20   용산구      30
# 21   은평구     101
# 22   종로구      63
# 23    중구      43
# 24   중랑구      62

# %% [markdown]
# ## 매핑

# %%
center = [37.566535, 126.9779692]
g_map = g.Map(location=center, zoom_start=18)

# %%
marker = g.Marker(location=[36.563296, 125.889305] , popup=df.loc[898]['사업장명'], icon=g.Icon(color='blue'))
marker.add_to(g_map)
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for i in range(np.shape(df)[0]):
    marker = g.Marker(location=[df.loc[i]['Latitude'], df.loc[i]['Longitude']] , popup=df.loc[i]['사업장명'], icon=g.Icon(color='blue'))
    marker.add_to(g_map)
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## 매핑

# %%
center = [37.566535, 126.9779692]
g_map = g.Map(location=center, zoom_start=18)

# %%
for i in range(np.shape(df)[0]):
    marker = g.Marker(location=[df.loc[i]['Latitude'], df.loc[i]['Longitude']] , popup=df.loc[i]['사업장명'], icon=g.Icon(color='blue'))
    marker.add_to(g_map)
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # 자치구별 반려동물출입가능 식당 개수

# %%
# 파일 불러오기
seoul_restaurant = pd.read_csv('./data/서울시/상권분석/서울관광재단_식당운영정보_20211231.csv', encoding='utf-8')

# 반려동물입장가능한 식당 추출
df_y = seoul_restaurant[seoul_restaurant['반려동물입장가능여부'] == 'Y']
df_y.reset_index(inplace=True)

# %%
# 불필요한 데이터 삭제
df = df_y.drop(['index','식당(ID)','반려동물입장가능여부','다국어메뉴판제공여부','휴무일정보내용', '영업시간내용', '택배판매유무',
       '배리어프리유무', '배달서비스유무', '예약방식명', '온라인예약정보내용', '홈페이지(URL)',
         '키오스크유무', '모바일페이먼트유무', '스마트오더유무',
       '입식좌석수', '좌식좌석수', '대표메뉴명'], axis=1)

# 결측치 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   식당명        225 non-null    object
#  1   지역명        225 non-null    object
#  2   주차가능여부     225 non-null    object
#  3   와이파이제공여부   225 non-null    object
#  4   놀이방유무      225 non-null    object
#  5   화장실정보내용    225 non-null    object
#  6   인근랜드마크명    194 non-null    object
#  7   인근랜드마크위도   193 non-null    float64
#  8   인근랜드마크경도   193 non-null    float64
#  9   인근랜드마크와거리  194 non-null    float64
# dtypes: float64(3), object(7)
# memory usage: 17.7+ KB

# %%
# '편리성' 열을 만들어 데이터 정규화
df['편리성(주차/와이파이/놀이방/화장실)'] = 0

for col in ['주차가능여부', '와이파이제공여부', '놀이방유무', '화장실정보내용']:
    df.loc[df[col]=='Y', col] = 1
    df.loc[df[col]=='N', col] = 0
    df['편리성(주차/와이파이/놀이방/화장실)'] = df['편리성(주차/와이파이/놀이방/화장실)'] + df[col]
    df.drop(col, axis=1, inplace=True)

# %%
# 지역명에서 자치구명만 추출하여 열 생성
df['지역명'] = df['지역명'].str.split()
df['자치구'] = [df['지역명'][i][1] for i in range(np.shape(df)[0])]

df = df.drop('지역명',axis=1)

# %%
# 결측치 제거 후 인덱스 정리
df = df.dropna(axis=0, inplace=False)
df = df.reset_index(drop=True)

# %%
df['자치구'].value_counts().index

restaurant_count = pd.DataFrame(columns=['자치구', '반려동물출입가능식당개수'],
                             data= {'자치구':df['자치구'].value_counts().index,
                                   '반려동물출입가능식당개수':df['자치구'].value_counts().values})

restaurant_count = restaurant_count.sort_values(by='자치구', ignore_index=True)

# %%
restaurant_count
# Out:
#      자치구  반려동물출입가능식당개수
# 0    강남구            20
# 1    강동구             6
# 2    강북구             3
# 3    강서구             3
# 4    관악구             2
# 5    광진구             6
# 6    구로구             3
# 7    금천구             1
# 8    노원구             3
# 9    도봉구             2
# 10  동대문구             3
# 11   동작구             5
# 12   마포구            48
# 13  서대문구             8
# 14   서초구            15
# 15   성동구            10
# 16   성북구             5
# 17   송파구             8
# 18   양천구             2
# 19  영등포구             5
# 20   용산구            12
# 21   은평구            10
# 22   종로구             5
# 23    중구             5
# 24   중랑구             3

# %%
# 편리성 높은 식당만 추출하여 객체 저장
# df_sorted = df.sort_values(by='편리성(주차/와이파이/놀이방/화장실)', ascending=False)
df_sorted = df_sorted[df_sorted['편리성(주차/와이파이/놀이방/화장실)'] == 3]

# %%
top2_restaurant_count = pd.DataFrame(columns=['자치구', '반려동물출입가능식당개수'],
                             data= {'자치구':df_sorted['자치구'].value_counts().index,
                                   '반려동물출입가능식당개수':df_sorted['자치구'].value_counts().values})

top2_restaurant_count
# Out:
#      자치구  반려동물출입가능식당개수
# 0    강남구             8
# 1    서초구             5
# 2    마포구             5
# 3    은평구             5
# 4    송파구             3
# 5   서대문구             3
# 6    성동구             3
# 7     중구             2
# 8   영등포구             2
# 9    강서구             2
# 10   구로구             2
# 11   용산구             2
# 12   강동구             2
# 13  동대문구             1
# 14   노원구             1
# 15   양천구             1
# 16   성북구             1
# 17   금천구             1
# 18   도봉구             1

# %%
pd.concat([restaurant_count, top2_restaurant_count], axis=1)
# Out:
#      자치구  반려동물출입가능식당개수   자치구  반려동물출입가능식당개수
# 0    마포구            48   강남구           8.0
# 1    강남구            20   서초구           5.0
# 2    서초구            15   마포구           5.0
# 3    용산구            12   은평구           5.0
# 4    은평구            10   송파구           3.0
# 5    성동구            10  서대문구           3.0
# 6   서대문구             8   성동구           3.0
# 7    송파구             8    중구           2.0
# 8    강동구             6  영등포구           2.0
# 9    광진구             6   강서구           2.0
# 10    중구             5   구로구           2.0
# 11  영등포구             5   용산구           2.0
# 12   동작구             5   강동구           2.0
# 13   성북구             5  동대문구           1.0
# 14   종로구             5   노원구           1.0
# 15   구로구             3   양천구           1.0
# 16  동대문구             3   성북구           1.0
# 17   강북구             3   금천구           1.0
# 18   노원구             3   도봉구           1.0
# 19   중랑구             3   NaN           NaN
# 20   강서구             3   NaN           NaN
# ...

# %% [markdown]
# # 법정동별 데이터

# %%
hospital_count = pd.read_csv('./data/서울시_법정동별_동물병원수.csv', encoding='cp949')
medicine_count = pd.read_csv('./data/서울시_법정동별_동물약국수.csv', encoding='cp949')

# %% [markdown]
# # 최종 df 로 저장

# %%
con = pd.concat([
    register_grouped, restaurant_count['반려동물출입가능식당개수'], 
           hospital_count['동물병원개수'],
           medicine_count['동물약국개수']], axis=1)

# %% [markdown]
# # 군집화

# %%
from sklearn.preprocessing import scale
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./data/서울시자치구별등록동물수.csv', encoding='cp949').iloc[:, 1:]

# %%
df
# Out:
#      자치구  등록동물수     소유자수  소유자당반려동물수  반려동물출입가능식당개수  동물병원개수  동물약국개수
# 0    강남구  31371  24141.0   1.299490            20      83     219
# 1    강동구  18281  14522.0   1.258849             6      54     100
# 2    강북구  31286  24304.0   1.287278             3      26      74
# 3    강서구  28055  21841.0   1.284511             3      47     117
# 4    관악구  25027  18669.0   1.340565             2      29      85
# 5    광진구   2672   2328.0   1.147766             6      32      61
# 6    구로구   8920   7470.0   1.194110             3      30      74
# 7    금천구  12650   9783.0   1.293059             1      17      47
# 8    노원구  28129  24591.0   1.143874             3      43      81
# 9    도봉구  14676      0.0        inf             2      25      59
# 10  동대문구  19565  14461.0   1.352949             3      28      69
# 11   동작구  18989  14820.0   1.281309             5      20      55
# 12   마포구  38948      0.0        inf            48      46      86
# ...

# %%
ing = df.drop(['자치구', '소유자당반려동물수'], axis=1)

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', max_iter=1000, random_state=0)
kmeans.fit(ing)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(max_iter=1000, n_clusters=5, random_state=0)

# %%
print(kmeans.labels_)
# Out:
# [3 1 3 3 1 2 2 2 3 4 1 1 0 0 1 4 1 3 4 1 1 3 2 2 1]

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', max_iter=1000, random_state=0)
kmeans.fit(ing_scaled_mm)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(max_iter=1000, n_clusters=5, random_state=0)

# %%
kmeans.labels_
# Out:
# array([0, 3, 3, 3, 3, 1, 1, 1, 3, 1, 3, 3, 4, 2, 3, 1, 3, 0, 2, 3, 1, 3,
#        1, 1, 3])

# %%
ing['target'] = kmeans.labels_

# %% [markdown]
# ## 군집 평가

# %% [markdown]
# ### 실루엣 분석

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

silhouette_score(ing, kmeans.labels_)
# Out:
# 0.21130623329781348

# %%
print(silhouette_samples(ing, kmeans.labels_))
silhouette_samples(ing, kmeans.labels_).mean()
# Out:
# [ 0.90588034  0.39615039 -0.95083233 -0.49102694  0.28040478  0.56313614
#   0.64169265  0.45199047 -0.68695063  0.55016689  0.48364547  0.47750634
#   0.         -0.66280239  0.36337931  0.4419308   0.514964    0.90139523
#  -0.33718561  0.46195669 -0.29914105 -0.56043449  0.64294306  0.65478353
#   0.53910318]
# 0.21130623329781348

# %% [markdown]
# # 스케일링

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Target 값을 제외한 모든 속성 값을 StandardScaler를 이용해 표준 정규 분포를 가지는 값들로 변환
scaler_ = MinMaxScaler()
scaler_.fit(ing.iloc[:, :-1])
ing_scaled = scaler_.transform(ing.iloc[:, :-1])

# %% [markdown]
# # PCA 차원 축소

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
ing_pca = pca.fit_transform(ing_scaled)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.56282317, 0.25648818])

# %%
ing_pca = pd.DataFrame(data=ing_pca, columns=['comp1', 'comp2'])
ing_pca['target'] = ing.target
ing_pca[:3]
# Out:
#       comp1     comp2  target
# 0  1.016851  0.383241       0
# 1  0.178106  0.011975       3
# 2  0.329792 -0.287647       3

# %%
# setosa는 세모, versicolor는 네모, virginica는 동그라미로 표현
markers=['^', 's', 'o', 'D', 'v']

# comp1을 x축, comp2를 y축으로 scatter plot 수행
for i, marker in enumerate(markers):
    x_axis_data = ing_pca[ing_pca['target']==i]['comp1']
    y_axis_data = ing_pca[ing_pca['target']==i]['comp2']
    plt.scatter(x_axis_data, y_axis_data, marker=marker, label=['A','B','C','D', 'E'][i])
    # plt.scatter(x_axis_data, y_axis_data)
    
plt.legend()
plt.xlabel('comp1')
plt.ylabel('comp2')
plt.show()
plt.savefig('./data/상권_clustering.png',
            facecolor='#eeeeee',
            edgecolor='black',
            format='png', dpi=200)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 노트

# %%
df['target'] = kmeans.labels_

# %%
df
# Out:
#      자치구  등록동물수     소유자수  소유자당반려동물수  반려동물출입가능식당개수  동물병원개수  동물약국개수  target
# 0    강남구  31371  24141.0   1.299490            20      83     219       0
# 1    강동구  18281  14522.0   1.258849             6      54     100       3
# 2    강북구  31286  24304.0   1.287278             3      26      74       3
# 3    강서구  28055  21841.0   1.284511             3      47     117       3
# 4    관악구  25027  18669.0   1.340565             2      29      85       3
# 5    광진구   2672   2328.0   1.147766             6      32      61       1
# 6    구로구   8920   7470.0   1.194110             3      30      74       1
# 7    금천구  12650   9783.0   1.293059             1      17      47       1
# 8    노원구  28129  24591.0   1.143874             3      43      81       3
# 9    도봉구  14676      0.0        inf             2      25      59       1
# 10  동대문구  19565  14461.0   1.352949             3      28      69       3
# 11   동작구  18989  14820.0   1.281309             5      20      55       3
# ...

# %%
df.sort_values('target', axis=0)
# Out:
#      자치구  등록동물수     소유자수  소유자당반려동물수  반려동물출입가능식당개수  동물병원개수  동물약국개수  target
# 0    강남구  31371  24141.0   1.299490            20      83     219       0
# 17   송파구  30488  24411.0   1.248945             8      68     172       0
# 22   종로구   9753   7288.0   1.338227             5      11      63       1
# 20   용산구  17717  12718.0   1.393065            12      29      30       1
# 5    광진구   2672   2328.0   1.147766             6      32      61       1
# 6    구로구   8920   7470.0   1.194110             3      30      74       1
# 7    금천구  12650   9783.0   1.293059             1      17      47       1
# 9    도봉구  14676      0.0        inf             2      25      59       1
# 23    중구   7922   5951.0   1.331205             5      19      43       1
# 15   성동구  16943      0.0        inf            10      30      49       1
# 18   양천구  24563      0.0        inf             2      49      76       2
# 13  서대문구  46266      0.0        inf             8      24      55       2
# ...

# %%
df[df['target'] == 3]
# Out:
#      자치구  등록동물수     소유자수  소유자당반려동물수  반려동물출입가능식당개수  동물병원개수  동물약국개수  target
# 1    강동구  18281  14522.0   1.258849             6      54     100       3
# 2    강북구  31286  24304.0   1.287278             3      26      74       3
# 3    강서구  28055  21841.0   1.284511             3      47     117       3
# 4    관악구  25027  18669.0   1.340565             2      29      85       3
# 8    노원구  28129  24591.0   1.143874             3      43      81       3
# 10  동대문구  19565  14461.0   1.352949             3      28      69       3
# 11   동작구  18989  14820.0   1.281309             5      20      55       3
# 14   서초구  23953  18748.0   1.277630            15      53     122       3
# 16   성북구  21877  16965.0   1.289537             5      33      64       3
# 19  영등포구  18825  14757.0   1.275666             5      33      89       3
# 21   은평구  28578  21868.0   1.306841            10      43     101       3
# 24   중랑구  19622  15454.0   1.269704             3      30      62       3

# %%
### 여러개의 클러스터링 갯수를 List로 입력 받아 각각의 실루엣 계수를 면적으로 시각화한 함수 작성
def visualize_silhouette(cluster_lists, X_features):     
    from sklearn.datasets import make_blobs
    from sklearn.cluster import KMeans
    from sklearn.metrics import silhouette_samples, silhouette_score

    import matplotlib.pyplot as plt
    import matplotlib.cm as cm
    import math
   
    # 입력값으로 클러스터링 갯수들을 리스트로 받아서, 각 갯수별로 클러스터링을 적용하고 실루엣 개수를 구함
    n_cols = len(cluster_lists)
   
    # plt.subplots()으로 리스트에 기재된 클러스터링 수만큼의 sub figures를 가지는 axs 생성 
    fig, axs = plt.subplots(figsize=(4*n_cols, 4), nrows=1, ncols=n_cols)
   
    # 리스트에 기재된 클러스터링 갯수들을 차례로 iteration 수행하면서 실루엣 개수 시각화
    for ind, n_cluster in enumerate(cluster_lists):
       
        # KMeans 클러스터링 수행하고, 실루엣 스코어와 개별 데이터의 실루엣 값 계산. 
        clusterer = KMeans(n_clusters = n_cluster, max_iter=500, random_state=0)
        cluster_labels = clusterer.fit_predict(X_features)
       
        sil_avg = silhouette_score(X_features, cluster_labels)
        sil_values = silhouette_samples(X_features, cluster_labels)
       
        y_lower = 10
        axs[ind].set_title('Number of Cluster : '+ str(n_cluster)+'\n' \
                          'Silhouette Score :' + str(round(sil_avg,3)) )
        axs[ind].set_xlabel("The silhouette coefficient values")
        axs[ind].set_ylabel("Cluster label")
        axs[ind].set_xlim([-0.1, 1])
        axs[ind].set_ylim([0, len(X_features) + (n_cluster + 1) * 10])
        axs[ind].set_yticks([])  # Clear the yaxis labels / ticks
        axs[ind].set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
       
        # 클러스터링 갯수별로 fill_betweenx( )형태의 막대 그래프 표현. 
        for i in range(n_cluster):
            ith_cluster_sil_values = sil_values[cluster_labels==i]
            ith_cluster_sil_values.sort()
           
            size_cluster_i = ith_cluster_sil_values.shape[0]
            y_upper = y_lower + size_cluster_i
           
            color = cm.nipy_spectral(float(i) / n_cluster)
            axs[ind].fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_sil_values, \
                                facecolor=color, edgecolor=color, alpha=0.7)
            axs[ind].text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
            y_lower = y_upper + 10

        axs[ind].axvline(x=sil_avg, color="red", linestyle="--")

# %%
visualize_silhouette([2, 3, 4, 5, 6,7,8], ing_scaled_mm)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...
